# %%
import pandas as pd


hat = pd.read_csv('./data/chick001.csv')
hat
# Out:
#   hatchery  chick
# 0        A     30
# 1        B     30
# 2        C     29
# 3        D     26
# 4        E     24
# 5        F     28
# 6        G     27

# %% [markdown]
# gpt>
# import pandas as pd:
#
#     이 부분은 pandas 라이브러리를 가져와서 데이터프레임과 데이터 조작을 위한 기능을 사용할 수 있도록 합니다.
#     pandas는 Python에서 데이터를 다루고 분석하는데 사용되는 강력한 라이브러리로,
#     표 형식의 데이터를 다루는 데 특히 유용합니다.
#     pd는 이 라이브러리를 더 간편하게 사용하기 위한 별칭(alias)입니다.

# %% [markdown]
# 2. 'chick'항목의 합계화 평균, 표준편차, 중앙값, 최소값, 최대값 구하기

# %%
hat_sum = hat['chick'].sum()
print(f'합계: {hat_sum}')

hat_mean = hat['chick'].mean()
print(f'평균: {hat_mean}')

hat_std = hat['chick'].std()
print(f'표준편차: {hat_std}')

hat_med = hat['chick'].median()
print(f'중앙값: {hat_med}')

hat_min = hat['chick'].min()
print(f'최소값: {hat_min}')

hat_max = hat['chick'].max()
print(f'합계: {hat_max}')
# Out:
# 합계: 194
# 평균: 27.714285714285715
# 표준편차: 2.2146697055682827
# 중앙값: 28.0
# 최소값: 24
# 합계: 30

# %%
hat['chick'].sum(),hat['chick'].mean(),hat['chick'].std(), hat['chick'].median(),hat['chick'].min(),hat['chick'].max()
# Out:
# (194, 27.714285714285715, 2.2146697055682827, 28.0, 24, 30)

# %%
hat.chick.sum(),hat.chick.mean(),hat.chick.std(),hat.chick.median(),hat.chick.min(),hat.chick.max()
# Out:
# (194, 27.714285714285715, 2.2146697055682827, 28.0, 24, 30)

# %% [markdown]
# gpt>  hat['chick'].sum()와 hat.chick.sum()은 Pandas 데이터프레임에서 열을 선택하여 해당 열의 합을 계산하는 방법입니다.
#
# hat['chick'].sum():
#
# 이 방법은 열에 대한 레이블을 사용하여 해당 열을 선택하고 합을 계산합니다.
#
# 괄호 안에 열 이름을 문자열로 넣어줍니다.
# 이 방법은 열 이름에 공백이나 특수 문자가 포함되어 있거나 변수명이 동적으로 생성되는 경우 유용합니다.
#
# hat.chick.sum():
#
# 이 방법은 열에 대한 속성으로 해당 열을 선택하고 합을 계산합니다.
#
# 열 이름에 공백이나 특수 문자가 없으며, 변수명이 정적으로 알려져 있는 경우에 사용하기 편리합니다.
#
# 두 방법의 결과는 동일하며, 선택된 열의 합을 반환합니다.
# 둘 중 어떤 방법을 사용할지는 코드의 가독성 및 편의성에 따라 달라집니다.
# 일반적으로는 두 방법 중 어떤 것을 사용해도 무방하며, 코드 스타일에 따라 선택하면 됩니다.

# %%
hat_sum = hat['chick'].sum()
hat_sum

hat_mean = hat['chick'].mean
hat_mean

hat_std = hat['chick'].std()
hat_std

hat_med = hat['chick'].median()
print(f'중앙값: {hat_med}')

hat_min = hat['chick'].min()
print(f'최소값: {hat_min}')

hat_max = hat['chick'].max()
print(f'합계: {hat_max}')
# Out:
# 중앙값: 28.0
# 최소값: 24
# 합계: 30

# %% [markdown]
# #3. chick 열을 기준으로 오름차순 정렬

# %%
chick_sorted = hat.sort_values(by=['chick'], ascending=True)
print(chick_sorted)
# Out:
#   hatchery  chick
# 4        E     24
# 3        D     26
# 6        G     27
# 5        F     28
# 2        C     29
# 0        A     30
# 1        B     30

# %%
chick_sorted = hat.sort_values(by='chick', ascending=True)
print(chick_sorted)
# Out:
#   hatchery  chick
# 4        E     24
# 3        D     26
# 6        G     27
# 5        F     28
# 2        C     29
# 0        A     30
# 1        B     30

# %% [markdown]
# gpt>
# chick_sorted = hat.sort_values(by=['chick'], ascending=True)와
# chick_sorted = hat.sort_values(by='chick', ascending=True)는
# 사실상 동일한 결과를 얻는 두 가지 표현 방식입니다.
#
# Pandas의 sort_values 메서드에서 by 파라미터에 열의 이름을 리스트로 전달하거나,
# 단일 열의 경우에는 리스트 없이 직접 열의 이름을 전달하는 두 가지 방법이 모두 허용됩니다.
#
# 따라서, 위의 두 코드 모두 hat 데이터프레임을 chick 열을 기준으로 오름차순으로 정렬한 결과를 반환합니다.
#
# 다만, 여러 열에 대해 정렬할 때는 열의 이름을 리스트로 전달해야 합니다.
# 아래는 여러 열에 대한 정렬의 예시입니다:
#
# python Copy code
# multi_sorted = hat.sort_values(by=['col1', 'col2'], ascending=[True, False])
# 여기서 col1은 오름차순으로, col2는 내림차순으로 정렬되어 multi_sorted 데이터프레임이 생성됩니다.

# %%
주어진 코드는 Pandas 데이터프레임에서 chick 열을 기준으로 정렬한 후, 정렬된 결과를 출력하는 코드입니다. 
여기에서는 sort_values 메서드를 사용하여 데이터를 정렬하고,
ascending=True를 설정하여 오름차순으로 정렬했습니다.

데이터프레임 정렬:

chick_sorted = hat.sort_values(by=['chick'], ascending=True)

sort_values 메서드는 데이터프레임을 지정된 열('chick')의 값을 기준으로 정렬합니다.
by 파라미터에는 정렬 기준이 되는 열의 이름을 리스트 형태로 전달합니다.

ascending=True는 오름차순으로 정렬하라는 옵션입니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 주어진 코드는 matplotlib.pyplot 라이브러리와 numpy 라이브러리를 가져오는 것입니다.
# 이 두 라이브러리는 데이터 시각화 및 수학적 연산에 사용되는 파이썬 라이브러리입니다.
#
# matplotlib.pyplot:
#
# 용도:
#     matplotlib은 그래프 및 차트를 그리기 위한 라이브러리로,
#     pyplot은 matplotlib의 하위 모듈 중 하나입니다.
#
# 사용법:
#     pyplot을 사용하면 간단하고 직관적으로 그래프를 그릴 수 있습니다.
#     plt는 pyplot을 일반적으로 줄여서 사용하는 관습적인 별칭입니다.
#
# pythonCopy code
# import matplotlib.pyplot as plt

# %% [markdown]
# numpy:
#
# 용도:
#     numpy는 다차원 배열과 행렬을 다루는 라이브러리로, 수학적 연산을 지원합니다.
#
# 사용법:
#     numpy를 사용하면 배열과 행렬을 효율적으로 다룰 수 있습니다.
#     np는 numpy를 일반적으로 줄여서 사용하는 관습적인 별칭입니다.
#
# python Copy code
# import numpy as np
#
# 따라서, 위의 코드는 matplotlib.pyplot을 plt로, numpy를 np로 각각 가져오는 것입니다.
# 이제 이들 라이브러리를 사용하여 데이터를 시각화하거나 수학적 연산을 수행할 수 있게 됩니다.

# %%
plt.rc('font', family='Malgun Gothic')                          # 한글 처리를 위함 - matplotlib
plt.rcParams['axes.unicode_minus'] = False            # 축의 음수 기호 표시를 위함.


plt.bar(hat['hatchery'],hat['chick'],color='green')     

plt.title('chick_sorted')
plt.xlabel('hatchery')
plt.ylabel('chick')

plt.show()

# %% [markdown]
# 주어진 코드는 matplotlib에서 한글 폰트를 설정하는 코드입니다.
#
# plt.rc('font', family='Malgun Gothic')는
# 한글 폰트를 'Malgun Gothic'으로 설정하고,
#
# plt.rcParams['axes.unicode_minus'] = False는
# 마이너스 기호(-)가 깨지는 것을 방지하기 위해 유니코드를 사용하도록 설정하는 코드입니다.
#
#
# plt.rc('font', family='Malgun Gothic'):
#
# rc는 matplotlib의 설정(configuration)을 변경하는 함수입니다.
#
# 'font'은 폰트 설정에 관련된 부분을 의미하며,
# family='Malgun Gothic'은 한글 폰트로 'Malgun Gothic'을 사용하겠다는 의미입니다.
#
# 한글 폰트를 설정함으로써 그래프의 축 레이블, 제목 등에 한글을 사용할 수 있게 됩니다.
#
# plt.rcParams['axes.unicode_minus'] = False:
#
# rcParams는 rc 함수를 통해 설정한 값들을 확인할 수 있는 딕셔너리 객체입니다.
#
# 'axes.unicode_minus'는 축(axis)에 유니코드를 사용할 때 마이너스 기호가 깨지지 않도록 하는 설정입니다.
#
# 기본적으로는 True로 설정되어 있어 유니코드를 사용할 경우 마이너스 기호가 깨지는데, 이를 False로 설정하여 깨지지 않도록 합니다.
#
# 따라서, 위의 코드는 matplotlib에서 한글 폰트를 설정하고 유니코드 마이너스 기호를 처리하기 위한 코드입니다.
# 이 설정을 통해 그래프에서 한글을 사용하거나 마이너스 기호가 깨지지 않도록 할 수 있습니다.

# %% [markdown]
# 주어진 코드는 matplotlib을 사용하여 막대 그래프(bar plot)를 생성하는 코드입니다. 각각의 함수와 파라미터에 대한 설명은 아래와 같습니다:
#
# plt.bar(hat['hatchery'], hat['chick'], color='green'):
#
# plt.bar: 막대 그래프를 그리는 함수입니다.
#     첫 번째 파라미터는 x 축의 값들, 두 번째 파라미터는 각 막대의 높이를 나타냅니다.
#
# hat['hatchery']: x 축에 사용될 값들로, hatchery 열의 데이터를 사용합니다.
#
# hat['chick']: 각 막대의 높이로, chick 열의 데이터를 사용합니다.
#
# color='green': 막대의 색상을 녹색으로 설정합니다.
#
# plt.title('chick_sorted'):
# plt.title: 그래프의 제목을 설정하는 함수입니다. 여기서는 'chick_sorted'라는 제목을 설정했습니다.
#
# plt.xlabel('hatchery'):
# plt.xlabel: x 축의 레이블을 설정하는 함수입니다. 여기서는 'hatchery'로 설정했습니다.
#
# plt.ylabel('chick'):
# plt.ylabel: y 축의 레이블을 설정하는 함수입니다. 여기서는 'chick'으로 설정했습니다.
#
# plt.show():
#
# plt.show: 그래프를 화면에 표시하는 함수입니다. 이 함수를 호출하지 않으면 그래프가 표시되지 않습니다.
#
# 따라서, 이 코드는 hat 데이터프레임의 hatchery 열을 x 축으로, chick 열을 y 축으로 하는 녹색 막대 그래프를 그리고, 그래프에 제목과 축 레이블을 추가하여 시각화하는 역할을 합니다.

# %%
plt.rc('font', family='Malgun Gothic')                          # 한글 처리를 위함 - matplotlib
plt.rcParams['axes.unicode_minus'] = False            # 축의 음수 기호 표시를 위함.


plt.bar(hat.hatchery,hat.chick,color='green')     

plt.title('chick_sorted')
plt.xlabel('hatchery')
plt.ylabel('chick')

plt.show()

# %% [markdown]
# plt.bar(hat['hatchery'], hat['chick'], color='green')와
# plt.bar(hat.hatchery, hat.chick, color='green')는 사실상 동일한 결과를 얻는 두 가지 표현 방식입니다.
#
# plt.bar(hat['hatchery'], hat['chick'], color='green'):
#
# 데이터프레임의 열을 선택할 때 열의 이름을 문자열로 전달합니다.
# 'hatchery'와 'chick'는 각각 hat 데이터프레임의 열을 나타냅니다.
#
# plt.bar(hat.hatchery, hat.chick, color='green'):
#
# 열의 이름을 문자열 대신에 직접 속성으로 접근합니다.
# hat.hatchery와 hat.chick는 각각 hat 데이터프레임의 열을 나타냅니다.
#
# 두 가지 표현 방식은 결과적으로 같은 값을 사용하므로 어느 것을 사용할지는 개인적인 취향에 따라 선택하면 됩니다.
# 일반적으로는 두 가지 표현 방식 중 편한 방식을 사용하는 것이 좋습니다.
#
# 단, 열의 이름에 공백이나 특수문자가 있는 경우에는 hat['column name'] 형태로 사용해야 합니다.

# %%
import seaborn as sns

col7=sns.color_palette('Pastel2',7)   #  Pastel2 색상에서 7가지 색상 가져와서 함. 

plt.figure(figsize=(10,7))

plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')

plt.title('부화장별 병아리 부화현황', fontsize=17)
plt.xlabel('부화장')
plt.ylabel('부화마릿수')

plt.show()

# %%
import seaborn as sns

col7=sns.color_palette('Pastel2',7)   #  Pastel2 색상에서 7가지 색상 가져와서 함. 

plt.figure(figsize=(30,17))

plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')

plt.title('부화장별 병아리 부화현황', fontsize=17)
plt.xlabel('부화장')
plt.ylabel('부화마릿수')

plt.show()

# %%
def addtext(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+0.5, y[i], ha='center')

# 막대 위에 텍스트 추가하기
col7 = sns.color_palette('Pastel2', 7)
plt.figure(figsize=(10, 7))

plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')

addtext(hat['hatchery'], hat['chick'])       # 텍스트 표시 사용자 정의 함수 추가

plt.title('부화장별 병아리 부화현황', fontsize =17)
plt.xlabel('부화장')
plt.ylabel('부화마릿수')
plt.show()

# %%
# 막대 위에 텍스트 추가하기
def addtext(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]-0.5, y[i], ha='center')

col7 = sns.color_palette('Pastel2', 7)
plt.figure(figsize=(10, 7))

plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')

addtext(hat['hatchery'], hat['chick'])       # 텍스트 표시 사용자 정의 함수 추가

plt.title('부화장별 병아리 부화현황', fontsize =17)
plt.xlabel('부화장')
plt.ylabel('부화마릿수')
plt.show()

# %%
# 막대 위에 텍스트 추가하기
def addtext(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]/2, y[i], ha='center')

col7 = sns.color_palette('Pastel2', 7)
plt.figure(figsize=(10, 7))

plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')

addtext(hat['hatchery'], hat['chick'])       # 텍스트 표시 사용자 정의 함수 추가

plt.title('부화장별 병아리 부화현황', fontsize =17)
plt.xlabel('부화장')
plt.ylabel('부화마릿수')
plt.show()

# %%
# 빨간색 수평선 추가하기
col7 = sns.color_palette('Pastel2', 7)
plt.figure(figsize=(10, 7))
plt.bar(hat['hatchery'], hat['chick'], color = col7, edgecolor = 'black')
addtext(hat['hatchery'], hat['chick']) # 텍스트 표시 사용자 정의 함수 추가
plt.hlines(30, -1, 7, colors = 'red', linestyles = 'dashed')
plt.title('부화장별 병아리 부화현황', fontsize =17)
plt.xlabel('부화장')
plt.ylabel('부화 마리 수')
plt.show()

# %%
# 파이차트 그리기 

col7 = sns.color_palette('Pastel2',7)
plt.figure(figsize=(10,10))
plt.pie(hat['chick'],labels=hat['hatchery'],autopct='%.1f%%',colors=col7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd

b = pd.read_csv('data/chick002.csv') # b 변수에 데이터셋 입력
b
# Out:
#    chick_nm  weight
# 0       b01      37
# 1       b02      39
# 2       b03      41
# 3       b04      45
# 4       b05      37
# 5       b06      33
# 6       b07      34
# 7       b08      31
# 8       b09      40
# 9       b10      41
# 10      b11      38
# 11      b12      43
# 12      b13      41
# 13      b14      38
# 14      b15      39
# 15      b16      42
# 16      b17      35
# 17      b18      33
# 18      b19      36
# 19      b20      44
# 20      b21      37
# 21      b22      41
# 22      b23      36
# 23      b24      39
# 24      b25      40
# 25      b26      39
# 26      b27      40
# 27      b28      36
# 28      b29      38
# 29      b30      39

# %%
b.describe()
# Out:
#           weight
# count  30.000000
# mean   38.400000
# std     3.286335
# min    31.000000
# 25%    36.250000
# 50%    39.000000
# 75%    40.750000
# max    45.000000

# %%
import matplotlib.pyplot as plt

plt.hist(b.weight,bins = 7)  # 7개 간격으로나누어라

plt.title('B 부화장 병아리 무게 분포 현황', fontsize =17)
plt.xlabel('병아리 무게(g)')
plt.ylabel('마리 수')
plt.show()

# %%
# 상자그림으로 무게의 분포 확인

import matplotlib.pyplot as plt

plt.boxplot(b.weight)

plt.title('B 부화장 병아리 무게 상자그림', fontsize = 17)
plt.ylabel('병아리 무게(g)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family = 'Malgun Gothic')               #한글 처리를 위함    -matplotlib
plt.rcParams['axes.unicode_minus'] = False    #축의 음수 기호 표시를 위함.

plt.subplot(1,1,1)
plt.hist(b.weight,bins= 7)  # 7개 간격으로나누어라

plt.title('B 부화장 병아리 무게 분포 현황', fontsize =17)
plt.xlabel('병아리 무게(g)')
plt.ylabel('마리 수')
# plt.show()    show를 마지막에 해야지 중간에 하면 찍고 찍게 됨.

plt.subplot(1,2,2)
plt.boxplot(b.weight)

plt.title('B 부화장 병아리 무게 상자그림', fontsize = 17)
plt.ylabel('병아리 무게(g)')
plt.show
# Out:
# C:\Users\JBEDU30\AppData\Local\Temp\ipykernel_16372\4238799324.py:15: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 히스토그램과 상자그림 한 번에 표시
plt.figure(figsize=(10, 12))
plt.subplot(1, 2, 1)
plt.hist(b.weight, bins = 7)
plt.title('B 부화장 병아리 무게 분포 현황', fontsize = 17)
plt.subplot(1, 2, 2)
plt.boxplot(b.weight, vert = False)  # vert = False 안 넣으면 세로 방향으로 보임
plt.show()

# %%
import pandas as pd
test = pd.read_csv('data/chick003.csv')  # test 변수에 데이터셋 입력
test
# Out:
#    hatchery chick_nm  weight
# 0         A      a01     112
# 1         A      a05     116
# 2         A      a09     106
# 3         A      a12     104
# 4         A      a15     116
# 5         A      a17     118
# 6         A      a26     110
# 7         A      a28     112
# 8         A      a29     106
# 9         A      a30     108
# 10        B      b01     100
# 11        B      b02     110
# 12        B      b07      98
# 13        B      b11     100
# 14        B      b13     104
# 15        B      b17     112
# 16        B      b22     106
# 17        B      b27     106
# 18        B      b28      96
# 19        B      b30     110

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.boxplot(x = 'weight', y='hatchery', data=test)
plt.title('부화장 A vs. B 무게 분포 비교', fontsize=17)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# import pandas as pd
# test = pd.read_csv('data/chick003.csv')  # test 변수에 데이터셋 입력
# test      
# 위 코드 위에서 실행 전제하에 아래 박스플랏

import seaborn as sns
plt.figure(figsize=(10,7))
sns.boxplot(x ='hatchery', y= 'weight', data=test)
plt.title('부화장 A vs. B 무게 분포 비교', fontsize=17)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 가설검정을 위해 scipy 패키지 불러오기 

import scipy as sp

# %%
# 부화장 A만 별도로 데이터셋 구성
test_a = test.loc[test.hatchery == 'A', 'weight']  # loc- lacation의 약자    테스트에서 해처리 항목 중A에서weight' 
test_a
# Out:
# 0    112
# 1    116
# 2    106
# 3    104
# 4    116
# 5    118
# 6    110
# 7    112
# 8    106
# 9    108
# Name: weight, dtype: int64

# %%
# 부화장 B만 별도로 데이터셋 구성
test_b = test.loc[test.hatchery == 'B', 'weight']
test_b
# Out:
# 10    100
# 11    110
# 12     98
# 13    100
# 14    104
# 15    112
# 16    106
# 17    106
# 18     96
# 19    110
# Name: weight, dtype: int64

# %%
# 부화장 A 샤피로 윌크 검정 실시 
sp.stats.shapiro(test_a)
# Out:
# ShapiroResult(statistic=0.9400018453598022, pvalue=0.5530338883399963)

# %% [markdown]
# p벨류 값이 0.05보다 작아야  귀무가설 기각인데
#
# p벨류 값이 0.05보다 크므로 귀무가설 채택
#
# 샤피로 윌크 검정 귀무가설은 - 정규분포를 이루고 있다 이므로
# 결론 정규분포를 이루고 있다

# %% [markdown]
# gpt>
#
#
# scipy.stats.shapiro 함수는 샤피로-윌크(Shapiro-Wilk) 검정을 수행하는 함수입니다.
# 이는 주어진 데이터 샘플이 정규 분포를 따르는지 여부를 검정하는 통계적인 방법 중 하나입니다.
#
# 함수의 인자 test_a는 정규성을 검정하려는 데이터 샘플을 나타냅니다.
# 이 함수는 두 개의 값을 반환합니다.
# 첫 번째 값은 통계량(Shapiro-Wilk 통계량), 두 번째 값은 해당 통계량에 대한 p-value입니다.
#
# 검정의 기본 가설은 다음과 같습니다:
#
# 귀무가설 (H0): 데이터는 정규 분포를 따른다.
# 대립가설 (H1): 데이터는 정규 분포를 따르지 않는다.
#
# 만약 p-value가 일정한 유의수준(일반적으로 0.05)보다 작다면,
# 귀무가설을 기각하고 대립가설을 채택할 수 있습니다.
# 따라서 작은 p-value는 데이터가 정규 분포를 따르지 않는다는 강력한 증거로 해석됩니다.
#
# 예를 들어, 코드 sp.stats.shapiro(test_a)의 결과가 (0.987, 0.123)이라면,
# 통계량이 0.987이고 p-value가 0.123이므로, 주어진 데이터가 정규 분포를 따르지 않을 가능성이 높지 않다고 할 수 있습니다.

# %%
# 부화장 B 샤피로 윌크 검정 실시 
sp.stats.shapiro(test_a)
# Out:
# ShapiroResult(statistic=0.9400018453598022, pvalue=0.5530338883399963)

# %%
# 부화장 A,B 두 집단 간 평균 검정
sp.stats.ttest_ind(test_a,test_b)
# Out:
# Ttest_indResult(statistic=2.842528280230058, pvalue=0.010803990633924202)

# %% [markdown]
# t-test 할때   stats 함수 필요
# t-test의 귀무가설은 두 집단의 평균은 같다
#
# 근데  pvalue값이 0.01로 0.05보다 작기 때문에 95% 신뢰수준에서 귀무가설 기각
#
# 결론, 귀무가설 기각
# 즉, 두 집단 간 평균은 서로 다르다고 판단.
