# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\jbedu30\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\jbedu30\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\jbedu30\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\jbedu30\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jbedu30\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jbedu30\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jbedu30\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jbedu30\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jbedu30\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jbedu30\anaconda3\lib\site-packages (from requests->folium) (2.0.4)

# %%
import pandas as pd
import folium

#대학교 정보 엑셀파일을 데이터프레임으로 변환
df=pd.read_excel('D:/2023_jsm_r/jupyter_2023_j/data/서울지역 대학교 위치.xlsx',engine='openpyxl')
print(df)

seoul_map = folium.Map(location=[37.5662952, 126.9779451], zoom_start=12)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.학교, df.위도, df.경도):
    folium.Marker([lat, lng], tooltip=name). add_to(seoul_map)

    #지도를 Html파일로 저장하기 
seoul_map.save('./seoul_colleges.html')
seoul_map
# Out:
#                 학교         위도          경도
# 0     KAIST 서울캠퍼스   37.592573  127.046737
# 1            KC대학교  37.548345  126.854797
# 2     가톨릭대학교(성신교정)  37.585922  127.004328
# 3     가톨릭대학교(성의교정)  37.499623  127.006065
# 4         감리교신학대학교  37.567645  126.961610
# 5            건국대학교  37.540762  127.079343
# 6     경기대학교 서울캠퍼스   37.300485  127.035833
# 7     경희대학교 서울캠퍼스   37.596195  127.052544
# 8            고려대학교  37.590700  127.027700
# 9            광운대학교  37.619496  127.059696
# 10           국민대학교  37.609641  126.997697
# 11         덕성여자대학교  37.651199  127.016160
# 12           동국대학교  37.557477  127.002052
# 13         동덕여자대학교  37.606320  127.041808
# 14    명지대학교 서울캠퍼스   37.580205  126.923445
# 15           삼육대학교  37.642952  127.105476
# 16    상명대학교 서울캠퍼스   37.602638  126.955252
# 17           서강대학교  37.550944  126.941002
# 18           서경대학교  37.615095  127.013111
# 19       서울과학기술대학교  37.631668  127.077481
# 20         서울교육대학교  37.489961  127.016412
# 21         서울기독대학교  37.600923  126.912382
# 22           서울대학교  37.459882  126.951905
# 23         서울시립대학교  37.583866  127.058777
# 24         서울여자대학교  37.628113  127.090457
# 25         서울한영대학교  37.496541  126.851262
# 26          성공회대학교  37.487232  126.825320
# 27  성균관대학교 서울캠퍼스    37.588227  126.993606
# 28         성신여자대학교  37.591310  127.022131
# 29           세종대학교  37.550260  127.073139
# 30         숙명여자대학교  37.546364  126.964831
# 31           숭실대학교  37.496311  126.957460
# 32           연세대학교  37.565784  126.938572
# 33          육군사관학교  37.623819  127.098878
# 34         이화여자대학교  37.564308  126.950179
# 35        장로회신학대학교  37.550511  127.103458
# 36    중앙대학교 서울캠퍼스   37.505088  126.957101
# 37           총신대학교  37.488623  126.966817
# 38         추계예술대학교  37.562452  126.953417
# 39       한국방송통신대학교  37.578613  127.003291
# 40         한국성서대학교  37.648749  127.064320
# 41        한국예술종합학교  37.604997  127.056740
# 42        한국외국어대학교  37.597319  127.057843
# 43         한국체육대학교  37.519627  127.130984
# 44           한성대학교  37.581785  127.010369
# 45           한양대학교  37.557232  127.045322
# 46           홍익대학교  37.551464  126.925011
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e383c9eef618e2fef0c061076e25e04f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e383c9eef618e2fef0c061076e25e04f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e383c9eef618e2fef0c061076e25e04f = L.map(
#                 &quot;map_e383c9eef618e2fef0c061076e25e04f&quot;,
#                 {
#                     center: [37.5662952, 126.9779451],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ab3351c9433b466fc61fa6199b0a2e2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             var marker_6ec08b8fca9fa0c7ea2377a2be0cf10b = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_6ec08b8fca9fa0c7ea2377a2be0cf10b.bindTooltip(
#                 `&lt;div&gt;
#                      KAIST 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e6c6b6dcd63a0d07c8fc0f6d9f14ec5 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_3e6c6b6dcd63a0d07c8fc0f6d9f14ec5.bindTooltip(
#                 `&lt;div&gt;
#                      KC대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1eed6040b2360bf161ebace8b1b01586 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_1eed6040b2360bf161ebace8b1b01586.bindTooltip(
#                 `&lt;div&gt;
#                      가톨릭대학교(성신교정)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_76868e7aecd0f49f4806e6f2f7b19865 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_76868e7aecd0f49f4806e6f2f7b19865.bindTooltip(
#                 `&lt;div&gt;
#                      가톨릭대학교(성의교정)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52687d59962aa18dc918168c4756f4b6 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_52687d59962aa18dc918168c4756f4b6.bindTooltip(
#                 `&lt;div&gt;
#                      감리교신학대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2337ced427e66e55a9b4627da2d15311 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_2337ced427e66e55a9b4627da2d15311.bindTooltip(
#                 `&lt;div&gt;
#                      건국대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d570675836669264c8942438d02d7c5f = L.marker(
#                 [37.30048499999999, 127.035833],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_d570675836669264c8942438d02d7c5f.bindTooltip(
#                 `&lt;div&gt;
#                      경기대학교 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_334f171561c23800f7dac592328f89d6 = L.marker(
#                 [37.5961951, 127.052544],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_334f171561c23800f7dac592328f89d6.bindTooltip(
#                 `&lt;div&gt;
#                      경희대학교 서울캠퍼스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d0d026f440cbe2bb9bf2c8d94fbccc5b = L.marker(
#                 [37.5907, 127.0277],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);
#
#
#             marker_d0d026f440cbe2bb9bf2c8d94fbccc5b.bindTooltip(
#                 `&lt;div&gt;
#                      고려대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a7f2ee8ab40d3e1b90c367a8ddb8882d = L.marker(
#                 [37.6194965, 127.0596958],
#                 {}
#             ).addTo(map_e383c9eef618e2fef0c061076e25e04f);

# %%
import csv
f1=open('D:/2023_jsm_r/jupyter_2023_j/data/LOCAL_PEOPLE_DONG_202309.csv',encoding='utf8')
data=csv.reader(f1)

next(data)
data=list(data)
print(len(data))
# Out:
# 295104

# %%
f2=open('D:/2023_jsm_r/jupyter_2023_j/data/dong_code.csv',encoding='utf8')
code_data=csv.reader(f2)
next(code_data)
next(code_data)
code_data=list(code_data)
print(len(code_data))
# Out:
# 424

# %%
print(data[0])
# Out:
# ['20230901', '00', '11305606', '16725.1626', '668.1093', '357.14589999999998', '387.14789999999999', '408.79559999999998', '383.45159999999998', '409.46260000000001', '502.96159999999998', '488.16449999999998', '657.4606', '611.87390000000005', '590.12310000000002', '502.65219999999999', '428.92230000000001', '1095.3970999999999', '463.52510000000001', '279.15960000000001', '401.27449999999999', '491.1533', '473.19170000000003', '465.23239999999998', '573.61540000000002', '431.49220000000003', '822.31500000000005', '686.10450000000003', '751.86239999999998', '658.57039999999995', '545.83820000000003', '2190.1595000000002', '']

# %%
print(code_data[0])
# Out:
# ['1101053', '11110530', '서울', '종로구', '사직동']

# %%
##생활인구수 데이터를 숫자로
for row in data:
    for i in range(1,32):
        if i<=2:
            row[i]=int(row[i])
        else:
            row[i]=float(row[i])
print(data[0])
# Out:
# ['20230901', 0, 11305606, 16725.1626, 668.1093, 357.1459, 387.1479, 408.7956, 383.4516, 409.4626, 502.9616, 488.1645, 657.4606, 611.8739, 590.1231, 502.6522, 428.9223, 1095.3971, 463.5251, 279.1596, 401.2745, 491.1533, 473.1917, 465.2324, 573.6154, 431.4922, 822.315, 686.1045, 751.8624, 658.5704, 545.8382, 2190.1595, '']

# %%
##생활인구수 데이터를 숫자로
for row in data:
    for i in range(1,-1):
        if i<=2:
            row[i]=int(row[i])
        else:
            row[i]=float(row[i])
print(data[0])
# Out:
# ['20230901', 0, 11305606, 16725.1626, 668.1093, 357.1459, 387.1479, 408.7956, 383.4516, 409.4626, 502.9616, 488.1645, 657.4606, 611.8739, 590.1231, 502.6522, 428.9223, 1095.3971, 463.5251, 279.1596, 401.2745, 491.1533, 473.1917, 465.2324, 573.6154, 431.4922, 822.315, 686.1045, 751.8624, 658.5704, 545.8382, 2190.1595, '']

# %%
## 행자부행정동코드를 정수로
for row in code_data:
     row[1]=int(row[1])    
print(code_data[0])
# Out:
# ['1101053', 11110530, '서울', '종로구', '사직동']

# %%
dong_name=input('행정동명을 입력: ')
for row in code_data:
    if row[-1] == dong_name:
        dong_code=row[1]
print(dong_name,'의 행정코드는', dong_code, '입니다')
# Out:
# 행정동명을 입력: 한남동
# 한남동 의 행정코드는 11170685 입니다

# %%
## 입력한 동의 9월 총 생활인구 수

s=0
for row in data:
    if row[2] ==dong_code:
        s+=row[3]

print(dong_name, '의 9월 총 생활인구수',s)
# Out:
# 하왕십리동 의 9월 총 생활인구수 28654764.261399996

# %%
## 입력한 동의 9월 0시 생활인구 합

s = 0
for row in data:
    if row[2] == dong_code and row[1]==0:
        s+=row[3]
print(dong_name, '0시 생활인구 합: ' ,  s)
# Out:
# 하왕십리동 0시 생활인구 합:  926459.2755

# %%
##입력한 동의 9월  0 시 평균, 15시 평균

# s0 = 0
# s15 =0
# cnt0 =0 
# cnt15 =0

s0, s15, cnt0, cnt15 =0,0,0,0

for row in data:
    if row[2] == dong_code and row[1]== 0 :
        s0 +=row[3] 
        cnt0 +=1
    elif row[2] == dong_code and row[1] == 15:
        s15 += row[3]
        cnt15 += 1

print(dong_name,'0시 생황인구 평균:' , s0/cnt0)
print(dong_name, '15시 생활인구 평균: ' ,  s15/cnt15)
# Out:
# 하왕십리동 0시 생황인구 평균: 31946.87156896552
# 하왕십리동 15시 생활인구 평균:  54309.603593103464

# %%
##입력한 동의 9월  0 시 ~, 23시까지 각각의 평균

# s =[]    
# for i in range(24):
#      s.append(0)      
# ctr + / 여러줄을 주석처리
# 시간대별 (0~23) 평균
    
s =[0 for i in range(24)]    

for row in data:
    if row[2] == dong_code :
        s[row[1]] += row[3]

print(s)

s=[j/30 for j in s]
print(s)
# Out:
# [926459.2755, 886922.2371, 851520.1192000001, 826116.1579000002, 817825.9042000001, 816475.9686, 858726.3419000001, 921600.7308000001, 1093969.3793000001, 1280067.1739999999, 1390588.2244000002, 1484037.8209, 1533572.3534000004, 1566697.7543999995, 1578779.1113, 1574978.5042000005, 1546850.4631, 1526292.9026000004, 1451267.2771000003, 1342128.9272, 1242286.5415999996, 1138386.7664000003, 1022542.1730999999, 976672.1532]
# [30881.97585, 29564.07457, 28384.003973333336, 27537.20526333334, 27260.86347333334, 27215.86562, 28624.21139666667, 30720.024360000003, 36465.645976666674, 42668.90579999999, 46352.94081333334, 49467.92736333333, 51119.07844666668, 52223.25847999998, 52625.970376666664, 52499.28347333335, 51561.68210333333, 50876.43008666668, 48375.575903333345, 44737.630906666665, 41409.55138666665, 37946.225546666676, 34084.73910333333, 32555.738439999997]

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='malgun gothic')
plt.title(dong_name + '시간대별 평균 인구')
plt.plot(range(24), s, color='indigo')
plt.xticks(range(24))
plt.xlabel("시간대")
plt.ylabel('평균인구수')
plt.show()

# %%
# Out:
# 행정동명을 입력: 하왕십리동
# 하왕십리동 의 행정코드는 11680545 입니다
# 하왕십리동 의 9월 총 생활인구수 28654764.261399996
# [926459.2755, 886922.2371, 851520.1192000001, 826116.1579000002, 817825.9042000001, 816475.9686, 858726.3419000001, 921600.7308000001, 1093969.3793000001, 1280067.1739999999, 1390588.2244000002, 1484037.8209, 1533572.3534000004, 1566697.7543999995, 1578779.1113, 1574978.5042000005, 1546850.4631, 1526292.9026000004, 1451267.2771000003, 1342128.9272, 1242286.5415999996, 1138386.7664000003, 1022542.1730999999, 976672.1532]
# [30881.97585, 29564.07457, 28384.003973333336, 27537.20526333334, 27260.86347333334, 27215.86562, 28624.21139666667, 30720.024360000003, 36465.645976666674, 42668.90579999999, 46352.94081333334, 49467.92736333333, 51119.07844666668, 52223.25847999998, 52625.970376666664, 52499.28347333335, 51561.68210333333, 50876.43008666668, 48375.575903333345, 44737.630906666665, 41409.55138666665, 37946.225546666676, 34084.73910333333, 32555.738439999997]

# %%
 # 2개동 비교

# %%
 # 2개동 비교
# 행정동 -1

dong_name1 = input("첫번째 행정동을 입력하세요  -->")
for row in code_data:
    if row[-1] == dong_name1:
        dong_code1= int(row[1])
        
# 행정동 -2
dong_name2 = input ( '두번째 행정동을 입력하세요 -->')
for row in code_data:
    if row[-1] == dong_name2:
        dong_code2= int(row[1])
        
population1 = [0 for i in range(24) ]
population2 = [0 for i in range(24) ]

for row in data:
    # 행정동 -1인 경우
    if row[2] == dong_code1:
        population1[row[1]] += row[3]
        
    # 행정동 -2인 경우 
    elif row[2] == dong_code2:
        population2[row[1]] += row[3]
        
population1 = [ p/30 for p in population1]
population2 = [ p/30 for p in population2]

plt.rc('font', family='Malgun Gothic')
plt.title(dong_name1 + '과' + dong_name2 + '시간대별 평균 인구')

plt.plot(range(24), population1, color='magenta', label=dong_name1)
plt.plot(range(24), population2, color='orange', label=dong_name2)
plt.legend()
plt.xlabel("시간대")
plt.ylabel('평균인구수')
plt.xticks(range(24), range(24))
plt.show()
# Out:
# 첫번째 행정동을 입력하세요  -->연남동
# 두번째 행정동을 입력하세요 -->한남동

# %%
# Out:
# 첫번째 행정동을 입력하세요 --> 상왕십리동
# 두번째 행정동을 입력하세요 --> 하왕십리동
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 19
#      15 population2 = [0 for i in range(24)]
#      17 for row in data:
#      18     # 행정동-1 인 경우
# ---> 19     if row[2] == dong_code1:
#      20         population1[row[1]] += row[3]
#      22     # 행정동-2 인 경우
#
# NameError: name 'dong_code1' is not defined

# %%
## 4~17열 : 남성
## 18~31 : 여성

import matplotlib.pyplot as plt

male = [ 0 for i in range(24)]
female = [ 0 for i in range(24)]

for row in data : 
    if row[2] == dong_code:
        male[row[1]] += sum(row[4:18])
        female[row[1]] += sum(row[18:32])
        
male = [m/30 for m in male]
female = [f/30 for f in female]
        
plt.rc('font', family='Malgun Gothic')
plt.title(dong_name + ' 남녀 시간대별 평균 인구')
plt.plot(range(24), male, color = 'b', label='남성')
plt.plot(range(24), female, color = 'r', label ='여성')
plt.xlabel('시간대')
plt.ylabel('평균인구수')
plt.legend()
plt.xticks(range(24), range(24))
plt.show()

# %%
male = [-m for m in male]
plt.rcParams['axes.unicode_minus'] =False

plt.rc('font', family='Malgun Gothic')
plt.title(dong_name + ' 남녀 시간대별 평균 인구')
plt.barh(range(24), male, color = 'b', label='남성')
plt.barh(range(24), female, color = 'r', label ='여성')
plt.xlabel('시간대')
plt.ylabel('평균인구수')
plt.legend()
plt.xticks(range(24), range(24))
plt.show()

# %%
male = [-m for m in male]
plt.rcParams['axes.unicode_minus'] =False

plt.rc('font', family='Malgun Gothic')
plt.title(dong_name + ' 남녀 시간대별 평균 인구')
plt.barh(range(24), male, color = 'b', label='남성')
plt.barh(range(24), female, color = 'r', label ='여성')
plt.ylabel('시간대')
plt.xlabel('평균인구수')
plt.legend()
plt.yticks(range(24), range(24))
plt.show()

# %%
##한남동 20대 남녀 시간대별 평균 인구 

import matplotlib.pyplot as plt

male20 = [ 0 for i in range(24)]
female20 = [ 0 for i in range(24)]

for row in data : 
    if row[2] == dong_code:
        male20[row[1]] += sum(row[7:9])
        female20[row[1]] += sum(row[21:23])
        
male = [m/30 for m in male20]
female = [f/30 for f in female20]
        
plt.rc('font', family='Malgun Gothic')
plt.title(dong_name + ' 한남동 20대 남녀 시간대별 평균 인구')
plt.plot(range(24), male20, color = 'b', label='남성')
plt.plot(range(24), female20, color = 'r', label ='여성')
plt.xlabel('시간대')
plt.ylabel('평균인구수')
plt.legend()
plt.xticks(range(24), range(24))
plt.show()

# %%
## 생활인구수를 기준으로 내림차순정렬 후 1~10 위 까지만 나타내기

# %%
import csv

# 인구 데이터 읽어와서 리스트로 저장하기
f1 = open('D:/2023_jsm_r/jupyter_2023_j/data/LOCAL_PEOPLE_DONG_202309.csv', encoding='utf8')    
data = csv.reader(f1)
next(data)
data = list(data)

# 행정동코드 데이터 불러와서 리스트로 저장하기
f2 = open('D:/2023_jsm_r/jupyter_2023_j/data/dong_code.csv', encoding='utf8')
code_data = csv.reader(f2)
next(code_data)
next(code_data)
code_data = list(code_data)

# 위치(위도,경도) 데이터 불러와서 리스트로 저장하기
f3 = open('D:/2023_jsm_r/jupyter_2023_j/data/dong_location.csv')
location_data = csv.reader(f3)
next(location_data)
location_data = list(location_data)

# 인구데이터의 데이터타입 변경하기 
for row in data : 
    for i in range(1, 32) : 
        if i <= 2 : 
            row[i] = int(row[i])
        else : 
            row[i] = float(row[i])
            
# 행정동코드 데이터의 데이터 타입 변환하기
for row in code_data :
    row[1] = int(row[1])
   
# 위치 정보 데이터의 데이터 타입 변환하기
for row in location_data :      ###  row[-2]:경도, row[-1]:위도
    row[-2], row[-1] = float(row[-2]), float(row[-1])

# %%
# 행정동별 인구수를 저장하는 빈 딕셔너리를 만들고 행정동별 총생활인구를 딕셔너리에 저장

dong_population = {}

for row in data:
    dong_code, p = row[2], row[3]
    if dong_code not in dong_population.keys():
        dong_population[dong_code]=p
    else:
        dong_population[dong_code] +=p
print(dong_population)
# Out:
# {11305606: 10078326.866100011, 11230710: 14823483.113200016, 11470570: 8362824.370399991, 11305620: 11916664.748299995, 11305600: 8199473.598499993, 11500615: 24086831.717800003, 11215770: 16766488.062100006, 11290640: 11967141.796900002, 11350640: 19171088.61189999, 11350630: 24727949.064300034, 11230560: 22292913.694199994, 11560700: 10609906.966200005, 11710566: 14820077.972499998, 11170650: 7812682.900999996, 11260580: 11681844.829700006, 11620525: 12214149.307900006, 11170630: 17301911.524599984, 11530790: 15344054.424300004, 11710642: 28658107.176800016, 11440590: 17046099.3479, 11350720: 8647506.347, 11380632: 8696252.316200007, 11560535: 35499664.735200025, 11680690: 11464848.821499998, 11620715: 6948849.771000001, 11440710: 12093454.446800014, 11680700: 32292671.52150001, 11230730: 13793453.422000017, 11230705: 14461249.101499975, 11590680: 16392003.86169999, 11500560: 12378839.28549998, 11620575: 15751766.650099998, 11200660: 14137768.168900004, 11500605: 7875920.8611999955, 11500570: 12073289.945900025, 11650560: 21965810.26910001, 11215740: 10671504.429700006, 11440565: 25249639.629300006, 11110615: 43788937.55249999, 11470650: 22680664.426, 11590640: 13050234.094200008, 11110560: 12235647.038999986, 11290610: 10816892.767099993, 11410615: 26983860.74649997, 11710550: 9573692.262299996, 11590560: 13247234.566599997, 11560710: 13499117.718900008, 11560670: 6856319.0082, 11200590: 9862681.1073, 11170625: 34769708.48489998, 11440680: 14864740.586500004, 11620735: 24602133.29290003, 11650531: 28106346.55359998, 11380590: 11159917.003199998, 11680600: 20647679.6814, 11740520: 28018108.81339999, 11740560: 14954999.540899996, 11500590: 18330368.202799987, 11200560: 17363140.614799995, 11545700: 7548117.971400001, 11590510: 24065580.0511, 11410565: 28781150.13389998, 11350710: 12006735.579399994, 11320670: 11777076.017100014, 11590650: 9424738.36309999, 11560660: 5265768.476600002, 11590630: 22407423.738199957, 11470640: 29108482.538, 11200535: 19641999.501, 11410685: 15587223.2363, 11620565: 15006910.051300004, 11260690: 12146720.248400016, 11170700: 7453241.5439, 11500630: 23241764.271899994, 11620615: 10157778.4822, 11590550: 11577284.441900006, 11530560: 23181755.384200007, 11500591: 13933069.037500015, 11140650: 5348598.2126999935, 11500520: 15272190.426700005, 11545630: 12594918.900700012, 11440720: 14663594.100399997, 11620725: 19635947.4926, 11440690: 13439586.092400007, 11710620: 25037937.537899997, 11470560: 10147789.084999984, 11320660: 11724690.597900001, 11590530: 30866512.273599986, 11410700: 15011231.034200013, 11590670: 12164606.576299995, 11620545: 7682242.560499996, 11440660: 50814483.53329998, 11350600: 32714875.17490003, 11560690: 12004257.141300006, 11740515: 34608741.74360002, 11650550: 2999042.4552999977, 11650580: 18490210.7268, 11140590: 16529996.006599985, 11170530: 11590171.791799998, 11305545: 24128673.90669999, 11470520: 15341403.068600018, 11350580: 16364150.619200004, 11710680: 31518958.353600036, 11140665: 7009826.666600003, 11320512: 19800608.369100016, 11530550: 13064619.726399995, 11560585: 10186717.240400013, 11215780: 10272292.9883, 11500620: 23881188.75430002, 11440585: 11145258.524499997, 11380625: 27817881.674499992, 11200720: 6526385.045400001, 11200620: 8375018.140999998, 11710690: 14038313.306300001, 11410585: 42266149.91200004, 11410555: 29527351.672199994, 11140570: 8804993.987000007, 11530520: 11214055.615700008, 11530595: 7403018.466400005, 11620645: 14559304.391099997, 11350595: 29656978.7445, 11560560: 25889120.65019999, 11680590: 28008181.445399985, 11380600: 17087561.943999995, 11470530: 12602733.916, 11350665: 14354595.501699993, 11530740: 20769232.22979997, 11350625: 21198115.8947, 11215730: 16089075.92349999, 11650540: 21763926.35139999, 11110710: 8237787.501599998, 11110630: 11611246.792299982, 11710641: 14597832.330599999, 11740690: 3309688.132699997, 11500604: 10701526.3404, 11470680: 14556214.874100015, 11560540: 68581818.43039998, 11260550: 7855389.347899996, 11260 ...

# %%
# 3. 인구수를 기준으로 내림차순 정력, 위에서 10개 항목만 별도로  저장

import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
print(top10)

top10_code = [t[0] for t in top10]
print(top10_code)
# Out:
# [(11680640, 71458480.62219994), (11560540, 68581818.43039998), (11440660, 50814483.53329998), (11650530, 44501744.07370002), (11110615, 43788937.55249999), (11410585, 42266149.91200004), (11545510, 40389995.36679996), (11380690, 39563796.63450001), (11740685, 38602817.3747), (11680650, 37097130.23050002)]
# [11680640, 11560540, 11440660, 11650530, 11110615, 11410585, 11545510, 11380690, 11740685, 11680650]

# %%
top10_name = [ 0 for i in range(10)]
top10_lat = [ 0 for i in range(10)]
top10_long = [ 0 for i in range(10)]

#4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code)):
    for row in code_data : 
        if row[1] == top10_code[i] :
            #행정동명 리스트에 저장하기
            top10_name[i] = row[-1]
            
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기 
    for row in location_data : 
        if row[3] == top10_name[i]:
            top10_lat[i], top10_long[i] = row[-1], row[-2]
             
       
print(top10_name)
print(top10_lat)
print(top10_long)
# Out:
# ['역삼1동', '여의도동', '서교동', '서초3동', '종로1.2.3.4가동', '신촌동', '가산동', '진관동', '길동', '역삼2동']
# [37.4999211, 37.5286662, 37.5550337, 37.4856591, 37.5777701, 37.5659638, 37.4756389, 37.64193, 37.5398758, 37.4984733]
# [127.0367584, 126.9290731, 126.9228533, 127.0097616, 126.9892737, 126.9384315, 126.8850721, 126.9387277, 127.1473638, 127.0449272]

# %%
# 6. 완성된 리스트 지도에 표시하기

import folium

for i in range(len(top10_name)):
    top10_name[i] =str(i+1)+'.'+top10_name[i]

map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12)
for i in range(10): 
    folium.Marker(
        [top10_lat[i], top10_long[i]], tooltip=top10_name[i],
        icon=folium.Icon(color='red', icon='star')
        ).add_to(map_top10)

map_top10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_087d19250e2d3f6c0d46a230de154e28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_087d19250e2d3f6c0d46a230de154e28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_087d19250e2d3f6c0d46a230de154e28 = L.map(
#                 &quot;map_087d19250e2d3f6c0d46a230de154e28&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ade0b059c82f4daa606d7d4b0b8bcf2a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var marker_cafd89ea7c8da7946796ffefdaeb8016 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var icon_4362206e7a03fc4fc7d595346c781947 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cafd89ea7c8da7946796ffefdaeb8016.setIcon(icon_4362206e7a03fc4fc7d595346c781947);
#
#
#             marker_cafd89ea7c8da7946796ffefdaeb8016.bindTooltip(
#                 `&lt;div&gt;
#                      1.역삼1동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6c3e4a15ca6f1a75a1c5d0715bbd5d04 = L.marker(
#                 [37.5286662, 126.9290731],
#                 {}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var icon_0886f8147ac15b025c8f9cb57b90c9e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c3e4a15ca6f1a75a1c5d0715bbd5d04.setIcon(icon_0886f8147ac15b025c8f9cb57b90c9e4);
#
#
#             marker_6c3e4a15ca6f1a75a1c5d0715bbd5d04.bindTooltip(
#                 `&lt;div&gt;
#                      2.여의도동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10d1d8b0ceb4fa6e8a3099d75bda9a12 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var icon_fea23baba69587f7ceb0400ed2119210 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10d1d8b0ceb4fa6e8a3099d75bda9a12.setIcon(icon_fea23baba69587f7ceb0400ed2119210);
#
#
#             marker_10d1d8b0ceb4fa6e8a3099d75bda9a12.bindTooltip(
#                 `&lt;div&gt;
#                      3.서교동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2766041746fc982acf45fd5d47952be7 = L.marker(
#                 [37.4856591, 127.0097616],
#                 {}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var icon_6eb79268c049568e7214c7928e8878e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2766041746fc982acf45fd5d47952be7.setIcon(icon_6eb79268c049568e7214c7928e8878e3);
#
#
#             marker_2766041746fc982acf45fd5d47952be7.bindTooltip(
#                 `&lt;div&gt;
#                      4.서초3동
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_31b53f71e3a2358898206484e109369c = L.marker(
#                 [37.5777701, 126.9892737],
#                 {}
#             ).addTo(map_087d19250e2d3f6c0d46a230de154e28);
#
#
#             var icon_4d02bdc3656ac77f97c64507b3b7dd4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31b53f71e3a2358898206484e109369c.setIcon(icon_4d02bdc3656ac77f9
